# %% [markdown]
# <a href="https://colab.research.google.com/github/PauloMendes81/PythonCertification/blob/main/the_picnic_basket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
basket = ["apple", "sandwish", "juice"]

print(basket[1])

basket[1]= "wrap"
basket.append("cookie")

print("Final basket:", basket)
print("Number of items:", len(basket))

for food in basket:
    print(food)
# Out:
# sandwish
# Final basket: ['apple', 'wrap', 'juice', 'cookie']
# Number of items: 4
# apple
# wrap
# juice
# cookie
